# %%
import spotipy
import sys
import spotipy.util as util

# %%
scope = 'user-library-read'
if len(sys.argv) >1:
    username = sys.argv[1]
else:
    print("Usage: %s username" %(sys.argv[0],))
    sys.exit()

token = util.prompt_for_user_token(username,scope,client_id = '5361fa0e7d3945f3b78faf916d34e7bb', 
                                   client_secret = 'e08fd9f28c23451f813b56dca6f31384', redirect_uri = 'http://localhost/')
# Out:
#             User authentication requires interaction with your
#             web browser. Once you enter your credentials and
#             give authorization, you will be redirected to
#             a url.  Paste that url you were directed to to
#             complete the authorization.
#
#
# Opened https://accounts.spotify.com/authorize?client_id=5361fa0e7d3945f3b78faf916d34e7bb&response_type=code&redirect_uri=http%3A%2F%2Flocalhost%2F&scope=user-library-read in your browser
#
#
# Enter the URL you were redirected to: http://localhost/?code=AQDGwb2ScGuw34ZStwhTl1ftjeffEnE3hG3SDRp0X8scGSLBsV-FIZo1h0qYrCvBhciBtjz5rZoAfxfTkh7eGZwgm5ZvZEjRKR4ivEICi5JZ6A3_bWXLeAAP9HjgIBoaMvhjPLClib77kPQwNO2PCloz5Fu95e760qZXcMLYFyk6B6PGzgYANvKwqb1RcOWNdY7L09BIqHo-yw

# %%
spotipy = spotipy.Spotify(auth=token)

# %%
user = spotipy.user('garrettg45')

# %%
spotipy.current_user_playlists(limit=50)
# Out:
# {'href': 'https://api.spotify.com/v1/users/garrettg45/playlists?offset=0&limit=50',
#  'items': [{'collaborative': False,
#    'description': '',
#    'external_urls': {'spotify': 'https://open.spotify.com/playlist/18aR2bHibLNXcgKrejZoms'},
#    'href': 'https://api.spotify.com/v1/playlists/18aR2bHibLNXcgKrejZoms',
#    'id': '18aR2bHibLNXcgKrejZoms',
#    'images': [{'height': 640,
#      'url': 'https://mosaic.scdn.co/640/09bd57e481adc5d6e5cd6d86b431d9718f26072a5ac91d99a266be79a77521e12f8a7150609a5c9a84e77a05d252259fe856295d4d91d7c8a4037688ef4e8721697b2cd1b2a2200f8031bb39726bbefe',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://mosaic.scdn.co/300/09bd57e481adc5d6e5cd6d86b431d9718f26072a5ac91d99a266be79a77521e12f8a7150609a5c9a84e77a05d252259fe856295d4d91d7c8a4037688ef4e8721697b2cd1b2a2200f8031bb39726bbefe',
#      'width': 300},
#     {'height': 60,
#      'url': 'https://mosaic.scdn.co/60/09bd57e481adc5d6e5cd6d86b431d9718f26072a5ac91d99a266be79a77521e12f8a7150609a5c9a84e77a05d252259fe856295d4d91d7c8a4037688ef4e8721697b2cd1b2a2200f8031bb39726bbefe',
#      'width': 60}],
#    'name': 'MASTER PARTY',
#    'owner': {'display_name': 'garrettg45',
#     'external_urls': {'spotify': 'https://open.spotify.com/user/garrettg45'},
#     'href': 'https://api.spotify.com/v1/users/garrettg45',
#     'id': 'garrettg45',
#     'type': 'user',
#     'uri': 'spotify:user:garrettg45'},
#    'primary_color': None,
#    'public': True,
#    'snapshot_id': 'MzksYTRlZmE2NDU1ZjY4NmQxNDAwMTVjNDFhODYyY2VjNWMxYjE0NDgwNg==',
#    'tracks': {'href': 'https://api.spotify.com/v1/playlists/18aR2bHibLNXcgKrejZoms/tracks',
#     'total': 98},
#    'type': 'playlist',
#    'uri': 'spotify:playlist:18aR2bHibLNXcgKrejZoms'},
#   {'collaborative': False,
#    'description': '',
#    'external_urls': {'spotify': 'https://open.spotify.com/playlist/0aSWXfJM9bTdbIh8E2K08o'},
#    'href': 'https://api.spotify.com/v1/playlists/0aSWXfJM9bTdbIh8E2K08o',
#    'id': '0aSWXfJM9bTdbIh8E2K08o',
#    'images': [{'height': 640,
#      'url': 'https://mosaic.scdn.co/640/0f995827d01ca2621d0a684506e50d2363f8ab4e9007d15564d59343d666d76e5defdabb337363dbab67616d0000b27381a6a2cafab2e7a4066b5eecab67616d0000b273f56213eede5f2e6a6065fb6d',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://mosaic.scdn.co/300/0f995827d01ca2621d0a684506e50d2363f8ab4e9007d15564d59343d666d76e5defdabb337363dbab67616d0000b27381a6a2cafab2e7a4066b5eecab67616d0000b273f56213eede5f2e6a6065fb6d',
#      'width': 300},
#     {'height': 60,
#      'url': 'https://mosaic.scdn.co/60/0f995827d01ca2621d0a684506e50d2363f8ab4e9007d15564d59343d666d76e5defdabb337363dbab67616d0000b27381a6a2cafab2e7a4066b5eecab67616d0000b273f56213eede5f2e6a6065fb6d',
#      'width': 60}],
#    'name': 'drip is forever',
#    'owner': {'display_name': 'garrettg45',
#     'external_urls': {'spotify': 'https://open.spotify.com/user/garrettg45'},
#     'href': 'https://api.spotify.com/v1/users/garrettg45',
#     'id': 'garrettg45',
#     'type': 'user',
#     'uri': 'spotify:user:garrettg45'},
#    'primary_color': None,
#    'public': True,
#    'snapshot_id': 'NjEsZDQ0NjE2ZDI4OTExZTRhMjExMjVmNGFjN2U4ZDdiZmJjOTI4OTRkOA==',
#    'tracks': {'href': 'https://api.spotify.com/v1/playlists/0aSWXfJM9bTdbIh8E2K08o/tracks',
#     'total': 29},
#    'type': 'playlist',
#    'uri': 'spotify:playlist:0aSWXfJM9bTdbIh8E2K08o'},
#   {'collaborative': False,
#    'description': '',
#    'external_urls': {'spotify': 'https://open.spotify.com/playlist/6dBzCrjYvAfqsfL91XDsNw'},
#    'href': 'https://api.spotify.com/v1/playlists/6dBzCrjYvAfqsfL91XDsNw',
#    'id': '6dBzCrjYvAfqsfL91XDsNw',
#    'images': [{'height': 640,
#      'url': 'https://mosaic.scdn.co/640/0572d477b7714828965bf1218a48b54d72749cb44cae9019efd7a9eaf2eb2d6eaf461614b92c12e8ab67616d0000b273683757f1fd40a7f7ef64bec1dc07e67e6bee12008b787550992fa7317c1eb00f',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://mosaic.scdn.co/300/0572d477b7714828965bf1218a48b54d72749cb44cae9019efd7a9eaf2eb2d6eaf461614b92c12e8ab67616d0000b273683757f1fd40a7f7ef64bec1dc07e67e6bee12008b787550992fa7317c1eb00f',
#      'width': 300},
#     {'height': 60,
#      'url': 'https://mosaic.scdn.co/60/0572d477b7714828965bf1218a48b54d72749cb44cae9019efd7a9eaf2eb2d6eaf461614b92c12e8ab67616d0000b273683757f1fd40a7f7ef64bec1dc07e67e6bee12008b787550992fa7317c1eb00f',
#      'width': 60}],
#    'name': '2020',
#    'owner': {'display_name': 'garrettg45',
#     'external_urls': {'spotify': 'https://open.spotify.com/user/garrettg45'},
#     'href': 'https://api.spotify.com/v1/users/garrettg45',
#     'id': 'garrettg45',
#     'type': 'user',
#     'uri': 'spotify:user:garrettg45'},
#    'primary_color': None,
#    'public': True,
#    'snapshot_id': 'MjUsNDgxN2Y3ODM0ZWE2MTBmODhlNWYwNjFlMzJhOWRkMWEyNWY5NDg1YQ==',
#    'tracks': {'href': 'https://api.spotify.com/v1/playlists/6dBzCrjYvAfqsfL91XDsNw/tracks',
#     'total': 20},
#    'type': 'playlist',
#    'uri': 'spotify:playlist:6dBzCrjYvAfqsfL91XDsNw'},
#   {'collaborative': False,
#    'description': '',
#    'external_urls': {'spotify': 'https://open.spotify.com/playlist/6yJ5Ysdg5lcGGFt1KrbMkB'},
#    'href': 'https://api.spotify.com/v1/playlists/6yJ5Ysdg5lcGGFt1KrbMkB',
#    'id': '6yJ5Ysdg5lcGGFt1KrbMkB',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/23ae786de5ab52466e195846455540c39f628d31',
#      'width': 640}],
#    'name': 'PBE DECADES',
#    'owner': {'display_name': 'garrettg45',
#     'external_urls': {'spotify': 'https://open.spotify.com/user/garrettg45'},
#     'href': 'https://api.spotify.com/v1/users/garrettg45',
#     'id': 'garrettg45',
#     'type': 'user',
#     'uri': 'spotify:user:garrettg45'},
#    'primary_color': None,
#    'public': True,
#    'snapshot_id': 'Myw1NDE1ZDUyOWY4OGVhMDgyMmEzYzZhNzcxNGE1YzBmODJhZTQ1ZTJh',
#    'tracks': {'href': 'https://api.spotify.com/v1/playlists/6yJ5Ysdg5lcGGFt1KrbMkB/tracks',
#     'total': 2},
#    'type': 'playlist',
#    'uri': 'spotify:playlist:6yJ5Ysdg5lcGGFt1KrbMkB'},
#   {'collaborative': False,
#    'description': '',
#    'external_urls': {'spotify': 'https://open.spotify.com/playlist/0OZrSeeq2YBa4WC53jWron'},
#    'href': 'https://api.spotify.com/v1/playlists/0OZrSeeq2YBa4WC53jWron',
#    'id': '0OZrSeeq2YBa4WC53jWron',
#    'images': [{'height': 640,
#      'url': 'https://mosaic.scdn.co/640/ab67616d0000b2735e8cc10ff27240cc3139b090ab67616d0000b27383182cdd2c0661ab4907dfb2acca2e7a1e842f02255f2f55b5a6292328f9fc07e85dc35551fbd35825d80f1cfdc235fad45027f8',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://mosaic.scdn.co/300/ab67616d0000b2735e8cc10ff27240cc3139b090ab67616d0000b27383182cdd2c0661ab4907dfb2acca2e7a1e842f02255f2f55b5a6292328f9fc07e85dc35551fbd35825d80f1cfdc235fad45027f8',
#      'width': 300},
#     {'height': 60,
#      'url': 'https://mosaic.scdn.co/60/ab67616d0000b2735e8cc10ff27240cc3139b090ab67616d0000b27383182cdd2c0661ab4907dfb2acca2e7a1e842f02255f2f55b5a6292328f9fc07e85dc35551fbd35825d80f1cfdc235fad45027f8',
#      'width': 60}],
#    'name': '\U0001f9e2\U0001f9e2\U0001f9e2',
#    'owner': {'display_name': 'garrettg45',
#     'external_urls': {'spotify': 'https://open.spotify.com/user/garrettg45'},
#     'href': 'https://api.spotify.com/v1/users/garrettg45',
#     'id': 'garrettg45',
#     'type': 'user',
#     'uri': 'spotify:user:garrettg45'},
#    'primary_color': None,
#    'public': True,
#    'snapshot_id': 'MjAsYTM4NDRmMjgwZjQ3NzI5YmI4NTkzM2ZjODZkYWU1ZmI5NTE4ZjMwNg==',
#    'tracks': {'href': 'https://api.spotify.com/v1/playlists/0OZrSeeq2YBa4WC53jWron/tracks',
#     'total': 19},
#    'type': 'playlist',
#    'uri': 'spotify:playlist:0OZrSeeq2YBa4WC53jWron'},
#   {'collaborative': False,
#    'description': '',
#    'external_urls': {'spotify': 'https://open.spotify.com/playlist/6pUoKhIVIWUDE1iIwdqmCa'},
#    'href': 'https://api.spotify.com/v1/playlists/6pUoKhIVIWUDE1iIwdqmCa',
#    'id': '6pUoKhIVIWUDE1iIwdqmCa',
#    'images': [{'height': 640,
#      'url': 'https://mosaic.scdn.co/640/30ea82bcf4b8237e931b991d8d5009f401edc712579d8b4a3b8d58be3c3e73c29725106882f4826bab67616d0000b2737e519297d9876b6afff2ab7bab67616d0000b273dcdf83db248a1b14719f8ec9',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://mosaic.scdn.co/300/30ea82bcf4b8237e931b991d8d5009f401edc712579d8b4a3b8d58be3c3e73c29725106882f4826bab67616d0000b2737e519297d9876b6afff2ab7bab67616d0000b273dcdf83db248a1b14719f8ec9',
#      'width': 300},
#     {'height': 60,
#      'url': 'https://mosaic.scdn.co/60/30ea82bcf4b8237e931b991d8d5009f401edc712579d8b4a3b8d58be3c3e73c29725106882f4826bab67616d0000b2737e519297d9876b6afff2ab7bab67616d0000b273dcdf83db248a1b14719f8ec9',
#      'width': 60}],
#    'name': 'roof aux',
#    'owner': {'display_name': 'garrettg45',
#     'external_urls': {'spotify': 'https://open.spotify.com/user/garrettg45'},
#     'href': 'https://api.spotify.com/v1/users/garrettg45',
#     'id': 'garrettg45',
#     'type': 'user',
#     'uri': 'spotify:user:garrettg45'},
#    'primary_color': None,
#    'public': True,
#    'snapshot_id': 'NDcsNzQ4NzFkMjEwOGZkYzJmMWFkMGQwN2I0MzAyYTI0MmZhNTMwNTljMg==',
#    'tracks': {'href': 'https://api.spotify.com/v1/playlists/6pUoKhIVIWUDE1iIwdqmCa/tracks',
#     'total': 44},
#    'type': 'playlist',
#    'uri': 'spotify:playlist:6pUoKhIVIWUDE1iIwdqmCa'},
#   {'collaborative': False,
#    'description': '',
#    'external_urls': {'spotify': 'https://open.spotify.com/playlist/68h9JAnfve5IUST3UPxCeE'},
#    'href': 'https://api.spotify.com/v1/playlists/68h9JAnfve5IUST3UPxCeE',
#    'id': '68h9JAnfve5IUST3UPxCeE',
#    'images': [{'height': 640,
#      'url': 'https://mosaic.scdn.co/640/2a179e1af43e9c0ecd99297d49b40caeb8f371576983416ed2934d891676f47c446327b0800a46f0ab67616d0000b273595101c281d7e229e1f0e6c4ab67616d0000b2737433176f037e0ba14190c34f',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://mosaic.scdn.co/300/2a179e1af43e9c0ecd99297d49b40caeb8f371576983416ed2934d891676f47c446327b0800a46f0ab67616d0000b273595101c281d7e229e1f0e6c4ab67616d0000b2737433176f037e0ba14190c34f',
#      'width': 300},
#     {'height': 60,
#      'url': 'https://mosaic.scdn.co/60/2a179e1af43e9c0ecd99297d49b40caeb8f371576983416ed2934d891676f47c446327b0800a46f0ab67616d0000b273595101c281d7e229e1f0e6c4ab67616d0000b2737433176f037e0ba14190c34f',
#      'width': 60}],
#    'name': '💧',
#    'owner': {'display_name': 'garrettg45',
#     'external_urls': {'spotify': 'https://open.spotify.com/user/garrettg45'},
#     'href': 'https://api.spotify.com/v1/users/garrettg45',
#     'id': 'garrettg45',
#     'type': 'user',
#     'uri': 'spotify:user:garrettg45'},
#    'primary_color': None,
#    'public': True,
#    'snapshot_id': 'MzUsZDliYzc5NDU5ODBhNGZmNmMwZjVjMzA0NWI3OTYyNTk1MzhmZTA1ZA==',
#    'tracks': {'href': 'https://api.spotify.com/v1/playlists/68h9JAnfve5IUST3UPxCeE/tracks',
#     'total': 59},
#    'type': 'playlist',
#    'uri': 'spotify:playlist:68h9JAnfve5IUST3UPxCeE'},
#   {'collaborative': False,
#    'description': '',
#    'external_urls': {'spotify': 'https://open.spotify.com/playlist/34LAjoJkStLMlo1aKX77tB'},
#    'href': 'https://api.spotify.com/v1/playlists/34LAjoJkStLMlo1aKX77tB',
#    'id': '34LAjoJkStLMlo1aKX77tB',
#    'images': [{'height': 640,
#      'url': 'https://mosaic.scdn.co/640/ab67616d0000b27326f8a0f6a4abe3088c6074adab67616d0000b273c9ae728eab2ea2dfc4466960ab67616d0000b273d00079f1e57754b0505de6caab67616d0000b273da3ca863175eb14e2959ca29',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://mosaic.scdn.co/300/ab67616d0000b27326f8a0f6a4abe3088c6074adab67616d0000b273c9ae728eab2ea2dfc4466960ab67616d0000b273d00079f1e57754b0505de6caab67616d0000b273da3ca863175eb14e2959ca29',
#      'width': 300},
#     {'height': 60,
#      'url': 'https://mosaic.scdn.co/60/ab67616d0000b27326f8a0f6a4abe3088c6074adab67616d0000b273c9ae728eab2ea2dfc4466960ab67616d0000b273d00079f1e57754b0505de6caab67616d0000b273da3ca863175eb14e2959ca29',
#      'width': 60}],
#    'name': 'WInter',
#    'owner': {'display_name': 'garrettg45',
#     'external_urls': {'spotify': 'https://open.spotify.com/user/garrettg45'},
#     'href': 'https://api.spotify.com/v1/users/garrettg45',
#     'id': 'garrettg45',
#     'type': 'user',
#     'uri': 'spotify:user:garrettg45'},
#    'primary_color': None,
#    'public': True,
#    'snapshot_id': 'MzEsMDZhNjZlYWIwMzYxYWUxM2E4OGRiZjE2Y2UwMmM2YzgyMGJmNjhjNA==',
#    'tracks': {'href': 'https://api.spotify.com/v1/playlists/34LAjoJkStLMlo1aKX77tB/tracks',
#     'total': 25},
#    'type': 'playlist',
#    'uri': 'spotify:playlist:34LAjoJkStLMlo1aKX77tB'},
#   {'collaborative': False,
#    'description': '',
#    'external_urls': {'spotify': 'https://open.spotify.com/playlist/0zp8xhyf5yk7MxW8fL5O3n'},
#    'href': 'https://api.spotify.com/v1/playlists/0zp8xhyf5yk7MxW8fL5O3n',
#    'id': '0zp8xhyf5yk7MxW8fL5O3n',
#    'images': [{'height': 640,
#      'url': 'https://mosaic.scdn.co/640/ab67616d0000b273ce9a92efb0c3ad4c2fb33072ab67616d0000b273ced248bb8dd18aa2da62f4f4ab67616d0000b273d79cfa3155b50beb5dbeeb9ae85dc35551fbd35825d80f1cfdc235fad45027f8',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://mosaic.scdn.co/300/ab67616d0000b273ce9a92efb0c3ad4c2fb33072ab67616d0000b273ced248bb8dd18aa2da62f4f4ab67616d0000b273d79cfa3155b50beb5dbeeb9ae85dc35551fbd35825d80f1cfdc235fad45027f8',
#      'width': 300},
#     {'height': 60,
#      'url': 'https://mosaic.scdn.co/60/ab67616d0000b273ce9a92efb0c3ad4c2fb33072ab67616d0000b273ced248bb8dd18aa2da62f4f4ab67616d0000b273d79cfa3155b50beb5dbeeb9ae85dc35551fbd35825d80f1cfdc235fad45027f8',
#      'width': 60}],
#    'name': 'TIM🅱️$',
#    'owner': {'display_name': 'garrettg45',
#     'external_urls': {'spotify': 'https://open.spotify.com/user/garrettg45'},
#     'href': 'https://api.spotify.com/v1/users/garrettg45',
#     'id': 'garrettg45',
#     'type': 'user',
#     'uri': 'spotify:user:garrettg45'},
#    'primary_color': None,
#    'public': True,
#    'snapshot_id': 'NTEsOGQ2NjcyN2NmNDhiMzVhNjQ3NGJjMTZiMDBkOGQ0OTQxODViMDhkNA==',
#    'tracks': {'href': 'https://api.spotify.com/v1/playlists/0zp8xhyf5yk7MxW8fL5O3n/tracks',
#     'total': 45},
#    'type': 'playlist',
#    'uri': 'spotify:playlist:0zp8xhyf5yk7MxW8fL5O3n'},
#   {'collaborative': False,
#    'description': '',
#    'external_urls': {'spotify': 'https://open.spotify.com/playlist/6QkIFpcGIwptJG8MijWlzj'},
#    'href': 'https://api.spotify.com/v1/playlists/6QkIFpcGIwptJG8MijWlzj',
#    'id': '6QkIFpcGIwptJG8MijWlzj',
#    'images': [{'height': 640,
#      'url': 'https://mosaic.scdn.co/640/249248e704f34007898ef0465f3c2b1c521d4347ab67616d0000b27310b4e67fdf606b6d97fc0d0bab67616d0000b273adb1732fa8d44b8eb2f6c0bfab67616d0000b273dcd504f678c14b1593605ff5',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://mosaic.scdn.co/300/249248e704f34007898ef0465f3c2b1c521d4347ab67616d0000b27310b4e67fdf606b6d97fc0d0bab67616d0000b273adb1732fa8d44b8eb2f6c0bfab67616d0000b273dcd504f678c14b1593605ff5',
#      'width': 300},
#     {'height': 60,
#      'url': 'https://mosaic.scdn.co/60/249248e704f34007898ef0465f3c2b1c521d4347ab67616d0000b27310b4e67fdf606b6d97fc0d0bab67616d0000b273adb1732fa8d44b8eb2f6c0bfab67616d0000b273dcd504f678c14b1593605ff5',
#      'width': 60}],
#    'name': 'dick cheney profited from the iraq war',
#    'owner': {'display_name': 'garrettg45',
#     'external_urls': {'spotify': 'https://open.spotify.com/user/garrettg45'},
#     'href': 'https://api.spotify.com/v1/users/garrettg45',
#     'id': 'garrettg45',
#     'type': 'user',
#     'uri': 'spotify:user:garrettg45'},
#    'primary_color': None,
#    'public': True,
#    'snapshot_id': 'NjMsZmI0NzY1MTE2Y2RmYmMyY2NmNTNmMDA5YzBhNDE3OTQ5ZmFmZDhlMg==',
#    'tracks': {'href': 'https://api.spotify.com/v1/playlists/6QkIFpcGIwptJG8MijWlzj/tracks',
#     'total': 59},
#    'type': 'playlist',
#    'uri': 'spotify:playlist:6QkIFpcGIwptJG8MijWlzj'},
#   {'collaborative': False,
#    'description': '',
#    'external_urls': {'spotify': 'https://open.spotify.com/playlist/6Et7sjTbCA5SlAtsmyc5qH'},
#    'href': 'https://api.spotify.com/v1/playlists/6Et7sjTbCA5SlAtsmyc5qH',
#    'id': '6Et7sjTbCA5SlAtsmyc5qH',
#    'images': [{'height': 640,
#      'url': 'https://mosaic.scdn.co/640/ab67616d0000b273bddf008ccaea655e61892c27ab67616d0000b273db953460d6de87c6d6788cb5d705d432adfa8bc09f008e77f4f2a311c4893cc1f7878fb2aed3301cd93e9e2853fea931639e2cc7',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://mosaic.scdn.co/300/ab67616d0000b273bddf008ccaea655e61892c27ab67616d0000b273db953460d6de87c6d6788cb5d705d432adfa8bc09f008e77f4f2a311c4893cc1f7878fb2aed3301cd93e9e2853fea931639e2cc7',
#      'width': 300},
#     {'height': 60,
#      'url': 'https://mosaic.scdn.co/60/ab67616d0000b273bddf008ccaea655e61892c27ab67616d0000b273db953460d6de87c6d6788cb5d705d432adfa8bc09f008e77f4f2a311c4893cc1f7878fb2aed3301cd93e9e2853fea931639e2cc7',
#      'width': 60}],
#    'name': '2019',
#    'owner': {'display_name': 'garrettg45',
#     'external_urls': {'spotify': 'https://open.spotify.com/user/garrettg45'},
#     'href': 'https://api.spotify.com/v1/users/garrettg45',
#     'id': 'garrettg45',
#     'type': 'user',
#     'uri': 'spotify:user:garrettg45'},
#    'primary_color': None,
#    'public': True,
#    'snapshot_id': 'MzA4LDZlYWZhNWIxOGRhZjVhNjM5YTIwZTBjMzMxNGJmMmNhMTljM2JiNDg=',
#    'tracks': {'href': 'https://api.spotify.com/v1/playlists/6Et7sjTbCA5SlAtsmyc5qH/tracks',
#     'total': 138},
#    'type': 'playlist',
#    'uri': 'spotify:playlist:6Et7sjTbCA5SlAtsmyc5qH'},
#   {'collaborative': False,
#    'description': '',
#    'external_urls': {'spotify': 'https://open.spotify.com/playlist/2wWqNuo4zjjdgLOktI3azG'},
#    'href': 'https://api.spotify.com/v1/playlists/2wWqNuo4zjjdgLOktI3azG',
#    'id': '2wWqNuo4zjjdgLOktI3azG',
#    'images': [{'height': 640,
#      'url': 'https://mosaic.scdn.co/640/ab67616d0000b273011bea9a2b6b25b84a1f611cab67616d0000b27303a8fccd2308b865a9dc3897ab67616d0000b2732ffd65ffee0b083f0d203638ab67616d0000b273487c522ebdb3af451b0db2ae',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://mosaic.scdn.co/300/ab67616d0000b273011bea9a2b6b25b84a1f611cab67616d0000b27303a8fccd2308b865a9dc3897ab67616d0000b2732ffd65ffee0b083f0d203638ab67616d0000b273487c522ebdb3af451b0db2ae',
#      'width': 300},
#     {'height': 60,
#      'url': 'https://mosaic.scdn.co/60/ab67616d0000b273011bea9a2b6b25b84a1f611cab67616d0000b27303a8fccd2308b865a9dc3897ab67616d0000b2732ffd65ffee0b083f0d203638ab67616d0000b273487c522ebdb3af451b0db2ae',
#      'width': 60}],
#    'name': 'STUDY',
#    'owner': {'display_name': 'garrettg45',
#     'external_urls': {'spotify': 'https://open.spotify.com/user/garrettg45'},
#     'href': 'https://api.spotify.com/v1/users/garrettg45',
#     'id': 'garrettg45',
#     'type': 'user',
#     'uri': 'spotify:user:garrettg45'},
#    'primary_color': None,
#    'public': True,
#    'snapshot_id': 'NDgsZGMyMmYxNjQ3NTI3ZTgwMjg4MzM0MWJhMWJkMDlmOGYzOTE0MWZlMg==',
#    'tracks': {'href': 'https://api.spotify.com/v1/playlists/2wWqNuo4zjjdgLOktI3azG/tracks',
#     'total': 37},
#    'type': 'playlist',
#    'uri': 'spotify:playlist:2wWqNuo4zjjdgLOktI3azG'},
#   {'collaborative': False,
#    'description': '',
#    'external_urls': {'spotify': 'https://open.spotify.com/playlist/4eSNrRQP2lS4ETEVcoUMoz'},
#    'href': 'https://api.spotify.com/v1/playlists/4eSNrRQP2lS4ETEVcoUMoz',
#    'id': '4eSNrRQP2lS4ETEVcoUMoz',
#    'images': [{'height': 640,
#      'url': 'https://mosaic.scdn.co/640/ab67616d0000b273072e9faef2ef7b6db63834a3ab67616d0000b273108ce80141155acc9b43dcc7ab67616d0000b2739ef69f2cf1038634bd541509ab67616d0000b273ea05ade87296171d1b4309fa',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://mosaic.scdn.co/300/ab67616d0000b273072e9faef2ef7b6db63834a3ab67616d0000b273108ce80141155acc9b43dcc7ab67616d0000b2739ef69f2cf1038634bd541509ab67616d0000b273ea05ade87296171d1b4309fa',
#      'width': 300},
#     {'height': 60,
#      'url': 'https://mosaic.scdn.co/60/ab67616d0000b273072e9faef2ef7b6db63834a3ab67616d0000b273108ce80141155acc9b43dcc7ab67616d0000b2739ef69f2cf1038634bd541509ab67616d0000b273ea05ade87296171d1b4309fa',
#      'width': 60}],
#    'name': '2018',
#    'owner': {'display_name': 'garrettg45',
#     'external_urls': {'spotify': 'https://open.spotify.com/user/garrettg45'},
#     'href': 'https://api.spotify.com/v1/users/garrettg45',
#     'id': 'garrettg45',
#     'type': 'user',
#     'uri': 'spotify:user:garrettg45'},
#    'primary_color': None,
#    'public': True,
#    'snapshot_id': 'MTM0LGY4M2I0ZTE3NTQ3MjZkN2Y3NTVkYzBiNmM0Zjc4YTAxYWVhYWQwZjY=',
#    'tracks': {'href': 'https://api.spotify.com/v1/playlists/4eSNrRQP2lS4ETEVcoUMoz/tracks',
#     'total': 87},
#    'type': 'playlist',
#    'uri': 'spotify:playlist:4eSNrRQP2lS4ETEVcoUMoz'},
#   {'collaborative': False,
#    'description': '',
#    'external_urls': {'spotify': 'https://open.spotify.com/playlist/7xsZs7sLXGogQj0KQWrELj'},
#    'href': 'https://api.spotify.com/v1/playlists/7xsZs7sLXGogQj0KQWrELj',
#    'id': '7xsZs7sLXGogQj0KQWrELj',
#    'images': [{'height': 640,
#      'url': 'https://mosaic.scdn.co/640/15b29a0823f17a8f2565d8a6e06c5d057747ab6fab67616d0000b273c7524a697e709517b50681b2ab67616d0000b273d77dbcd4dbd37cdfa61771fadb2e1b8c1295cfd88edad5594f34d088fb8fb29b',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://mosaic.scdn.co/300/15b29a0823f17a8f2565d8a6e06c5d057747ab6fab67616d0000b273c7524a697e709517b50681b2ab67616d0000b273d77dbcd4dbd37cdfa61771fadb2e1b8c1295cfd88edad5594f34d088fb8fb29b',
#      'width': 300},
#     {'height': 60,
#      'url': 'https://mosaic.scdn.co/60/15b29a0823f17a8f2565d8a6e06c5d057747ab6fab67616d0000b273c7524a697e709517b50681b2ab67616d0000b273d77dbcd4dbd37cdfa61771fadb2e1b8c1295cfd88edad5594f34d088fb8fb29b',
#      'width': 60}],
#    'name': 'La Campaña',
#    'owner': {'display_name': 'garrettg45',
#     'external_urls': {'spotify': 'https://open.spotify.com/user/garrettg45'},
#     'href': 'https://api.spotify.com/v1/users/garrettg45',
#     'id': 'garrettg45',
#     'type': 'user',
#     'uri': 'spotify:user:garrettg45'},
#    'primary_color': None,
#    'public': True,
#    'snapshot_id': 'MjgsYzI2OWVhODdhYzU4ZWM5ODY4ZjczYjMwMGZiZjM4N2I4MDZjZTc4MQ==',
#    'tracks': {'href': 'https://api.spotify.com/v1/playlists/7xsZs7sLXGogQj0KQWrELj/tracks',
#     'total': 22},
#    'type': 'playlist',
#    'uri': 'spotify:playlist:7xsZs7sLXGogQj0KQWrELj'},
#   {'collaborative': False,
#    'description': '',
#    'external_urls': {'spotify': 'https://open.spotify.com/playlist/5F4D9oVDqnYtmMbht0hd2W'},
#    'href': 'https://api.spotify.com/v1/playlists/5F4D9oVDqnYtmMbht0hd2W',
#    'id': '5F4D9oVDqnYtmMbht0hd2W',
#    'images': [{'height': 640,
#      'url': 'https://mosaic.scdn.co/640/ab67616d0000b2732ffd65ffee0b083f0d203638ab67616d0000b27361f1b52d92c907a8645fd881ab67616d0000b273adb1732fa8d44b8eb2f6c0bff3be8b0c507c34caa4655e73e36c49407809bdcb',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://mosaic.scdn.co/300/ab67616d0000b2732ffd65ffee0b083f0d203638ab67616d0000b27361f1b52d92c907a8645fd881ab67616d0000b273adb1732fa8d44b8eb2f6c0bff3be8b0c507c34caa4655e73e36c49407809bdcb',
#      'width': 300},
#     {'height': 60,
#      'url': 'https://mosaic.scdn.co/60/ab67616d0000b2732ffd65ffee0b083f0d203638ab67616d0000b27361f1b52d92c907a8645fd881ab67616d0000b273adb1732fa8d44b8eb2f6c0bff3be8b0c507c34caa4655e73e36c49407809bdcb',
#      'width': 60}],
#    'name': 'airbag',
#    'owner': {'display_name': 'garrettg45',
#     'external_urls': {'spotify': 'https://open.spotify.com/user/garrettg45'},
#     'href': 'https://api.spotify.com/v1/users/garrettg45',
#     'id': 'garrettg45',
#     'type': 'user',
#     'uri': 'spotify:user:garrettg45'},
#    'primary_color': None,
#    'public': True,
#    'snapshot_id': 'NTQsNjNiMmVhZTA4NGNiOGU0YWE0OWM1YmZmYmQ0M2NlYTdjMDY4ZDBkZQ==',
#    'tracks': {'href': 'https://api.spotify.com/v1/playlists/5F4D9oVDqnYtmMbht0hd2W/tracks',
#     'total': 45},
#    'type': 'playlist',
#    'uri': 'spotify:playlist:5F4D9oVDqnYtmMbht0hd2W'},
#   {'collaborative': False,
#    'description': '',
#    'external_urls': {'spotify': 'https://open.spotify.com/playlist/2H1xlmBRXGMNY7s9GtUz5d'},
#    'href': 'https://api.spotify.com/v1/playlists/2H1xlmBRXGMNY7s9GtUz5d',
#    'id': '2H1xlmBRXGMNY7s9GtUz5d',
#    'images': [{'height': 640,
#      'url': 'https://mosaic.scdn.co/640/0b1efc4b13497878228d168ca287dc2b7da87a39322f6eafde1c7b8e531309973702770281292f07ab67616d0000b273a48d6e59508fdea34a66cd2fab67616d0000b273b518678eea515c97db0c69f1',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://mosaic.scdn.co/300/0b1efc4b13497878228d168ca287dc2b7da87a39322f6eafde1c7b8e531309973702770281292f07ab67616d0000b273a48d6e59508fdea34a66cd2fab67616d0000b273b518678eea515c97db0c69f1',
#      'width': 300},
#     {'height': 60,
#      'url': 'https://mosaic.scdn.co/60/0b1efc4b13497878228d168ca287dc2b7da87a39322f6eafde1c7b8e531309973702770281292f07ab67616d0000b273a48d6e59508fdea34a66cd2fab67616d0000b273b518678eea515c97db0c69f1',
#      'width': 60}],
#    'name': 'DISCOVER WEEKLY BANGERS',
#    'owner': {'display_name': 'garrettg45',
#     'external_urls': {'spotify': 'https://open.spotify.com/user/garrettg45'},
#     'href': 'https://api.spotify.com/v1/users/garrettg45',
#     'id': 'garrettg45',
#     'type': 'user',
#     'uri': 'spotify:user:garrettg45'},
#    'primary_color': None,
#    'public': True,
#    'snapshot_id': 'MTY3LDRkM2RmZTc2NTBkMzQwZTljZDBhNjdjMGQ2OGJlYWMyYTVjMzk4ZWU=',
#    'tracks': {'href': 'https://api.spotify.com/v1/playlists/2H1xlmBRXGMNY7s9GtUz5d/tracks',
#     'total': 159},
#    'type': 'playlist',
#    'uri': 'spotify:playlist:2H1xlmBRXGMNY7s9GtUz5d'},
#   {'collaborative': False,
#    'description': '',
#    'external_urls': {'spotify': 'https://open.spotify.com/playlist/39PXR7sjTxE1tDovCyxeec'},
#    'href': 'https://api.spotify.com/v1/playlists/39PXR7sjTxE1tDovCyxeec',
#    'id': '39PXR7sjTxE1tDovCyxeec',
#    'images': [{'height': 640,
#      'url': 'https://mosaic.scdn.co/640/ab67616d0000b27315cfde01c2c08b28edbb4b4fab67616d0000b2734246e3158421f5abb75abc4fab67616d0000b2738c75413c7f38b3f512a75b35ab67616d0000b273940b54f90834834dfbc53da1',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://mosaic.scdn.co/300/ab67616d0000b27315cfde01c2c08b28edbb4b4fab67616d0000b2734246e3158421f5abb75abc4fab67616d0000b2738c75413c7f38b3f512a75b35ab67616d0000b273940b54f90834834dfbc53da1',
#      'width': 300},
#     {'height': 60,
#      'url': 'https://mosaic.scdn.co/60/ab67616d0000b27315cfde01c2c08b28edbb4b4fab67616d0000b2734246e3158421f5abb75abc4fab67616d0000b2738c75413c7f38b3f512a75b35ab67616d0000b273940b54f90834834dfbc53da1',
#      'width': 60}],
#    'name': '🎁🎁🎁',
#    'owner': {'display_name': 'garrettg45',
#     'external_urls': {'spotify': 'https://open.spotify.com/user/garrettg45'},
#     'href': 'https://api.spotify.com/v1/users/garrettg45',
#     'id': 'garrettg45',
#     'type': 'user',
#     'uri': 'spotify:user:garrettg45'},
#    'primary_color': None,
#    'public': True,
#    'snapshot_id': 'MTcsODVmYjlkMDRhY2FjODNlYWQ3ZTUwODY0NzA2MTZhOThhOTRkZDcwNw==',
#    'tracks': {'href': 'https://api.spotify.com/v1/playlists/39PXR7sjTxE1tDovCyxeec/tracks',
#     'total': 11},
#    'type': 'playlist',
#    'uri': 'spotify:playlist:39PXR7sjTxE1tDovCyxeec'},
#   {'collaborative': False,
#    'description': '',
#    'external_urls': {'spotify': 'https://open.spotify.com/playlist/25hoGQMzw6qYUhNJ0WmOxr'},
#    'href': 'https://api.spotify.com/v1/playlists/25hoGQMzw6qYUhNJ0WmOxr',
#    'id': '25hoGQMzw6qYUhNJ0WmOxr',
#    'images': [{'height': 640,
#      'url': 'https://mosaic.scdn.co/640/ab67616d0000b273011bea9a2b6b25b84a1f611cab67616d0000b273509cef30f965f28a3a649afaab67616d0000b273a55f73b70360daa13f3f30c2ad92616356c6ab6877ef252c614f89a7408ade20',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://mosaic.scdn.co/300/ab67616d0000b273011bea9a2b6b25b84a1f611cab67616d0000b273509cef30f965f28a3a649afaab67616d0000b273a55f73b70360daa13f3f30c2ad92616356c6ab6877ef252c614f89a7408ade20',
#      'width': 300},
#     {'height': 60,
#      'url': 'https://mosaic.scdn.co/60/ab67616d0000b273011bea9a2b6b25b84a1f611cab67616d0000b273509cef30f965f28a3a649afaab67616d0000b273a55f73b70360daa13f3f30c2ad92616356c6ab6877ef252c614f89a7408ade20',
#      'width': 60}],
#    'name': 'Cymbal',
#    'owner': {'display_name': 'garrettg45',
#     'external_urls': {'spotify': 'https://open.spotify.com/user/garrettg45'},
#     'href': 'https://api.spotify.com/v1/users/garrettg45',
#     'id': 'garrettg45',
#     'type': 'user',
#     'uri': 'spotify:user:garrettg45'},
#    'primary_color': None,
#    'public': True,
#    'snapshot_id': 'MjcsNTFjODRiMzY4MTYxNDMyYzViYzk4NThjMWYyZGIwNjI1MDdkMGM4Mw==',
#    'tracks': {'href': 'https://api.spotify.com/v1/playlists/25hoGQMzw6qYUhNJ0WmOxr/tracks',
#     'total': 23},
#    'type': 'playlist',
#    'uri': 'spotify:playlist:25hoGQMzw6qYUhNJ0WmOxr'},
#   {'collaborative': False,
#    'description': '',
#    'external_urls': {'spotify': 'https://open.spotify.com/playlist/2wswZK7pOLZQeviT0qSwsW'},
#    'href': 'https://api.spotify.com/v1/playlists/2wswZK7pOLZQeviT0qSwsW',
#    'id': '2wswZK7pOLZQeviT0qSwsW',
#    'images': [{'height': 640,
#      'url': 'https://mosaic.scdn.co/640/ab67616d0000b2732d6a3edf8a8b6988270fb939ab67616d0000b273be634898c4b925ad6611ac64c46325c0ffe1d03463c7927bb63883a28243a8afd6d9f018514018a9a4dff4996696050b3c17f9ee',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://mosaic.scdn.co/300/ab67616d0000b2732d6a3edf8a8b6988270fb939ab67616d0000b273be634898c4b925ad6611ac64c46325c0ffe1d03463c7927bb63883a28243a8afd6d9f018514018a9a4dff4996696050b3c17f9ee',
#      'width': 300},
#     {'height': 60,
#      'url': 'https://mosaic.scdn.co/60/ab67616d0000b2732d6a3edf8a8b6988270fb939ab67616d0000b273be634898c4b925ad6611ac64c46325c0ffe1d03463c7927bb63883a28243a8afd6d9f018514018a9a4dff4996696050b3c17f9ee',
#      'width': 60}],
#    'name': '👴🏿👴🏿👴🏿',
#    'owner': {'display_name': 'garrettg45',
#     'external_urls': {'spotify': 'https://open.spotify.com/user/garrettg45'},
#     'href': 'https://api.spotify.com/v1/users/garrettg45',
#     'id': 'garrettg45',
#     'type': 'user',
#     'uri': 'spotify:user:garrettg45'},
#    'primary_color': None,
#    'public': True,
#    'snapshot_id': 'NDAsNTU2ZWJmZWJlOTIwYWVlZTJkZjRiZmE2MzZmZTBlNjAwNGVlZDBjNQ==',
#    'tracks': {'href': 'https://api.spotify.com/v1/playlists/2wswZK7pOLZQeviT0qSwsW/tracks',
#     'total': 38},
#    'type': 'playlist',
#    'uri': 'spotify:playlist:2wswZK7pOLZQeviT0qSwsW'},
#   {'collaborative': False,
#    'description': '',
#    'external_urls': {'spotify': 'https://open.spotify.com/playlist/5qxo1BUop98plBCslmwISf'},
#    'href': 'https://api.spotify.com/v1/playlists/5qxo1BUop98plBCslmwISf',
#    'id': '5qxo1BUop98plBCslmwISf',
#    'images': [{'height': 640,
#      'url': 'https://mosaic.scdn.co/640/253363c751fbc46e93fe73dd7ff8508ab39d61122a179e1af43e9c0ecd99297d49b40caeb8f371575a8efefdba4562114d38e0deddd49635550f428cab67616d0000b27381a6a2cafab2e7a4066b5eec',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://mosaic.scdn.co/300/253363c751fbc46e93fe73dd7ff8508ab39d61122a179e1af43e9c0ecd99297d49b40caeb8f371575a8efefdba4562114d38e0deddd49635550f428cab67616d0000b27381a6a2cafab2e7a4066b5eec',
#      'width': 300},
#     {'height': 60,
#      'url': 'https://mosaic.scdn.co/60/253363c751fbc46e93fe73dd7ff8508ab39d61122a179e1af43e9c0ecd99297d49b40caeb8f371575a8efefdba4562114d38e0deddd49635550f428cab67616d0000b27381a6a2cafab2e7a4066b5eec',
#      'width': 60}],
#    'name': '🚬🚬🚬',
#    'owner': {'display_name': 'garrettg45',
#     'external_urls': {'spotify': 'https://open.spotify.com/user/garrettg45'},
#     'href': 'https://api.spotify.com/v1/users/garrettg45',
#     'id': 'garrettg45',
#     'type': 'user',
#     'uri': 'spotify:user:garrettg45'},
#    'primary_color': None,
#    'public': True,
#    'snapshot_id': 'NTUsYjVhMDUyNTY5NjZkMzY3ODM0NTBjM2MzZDUwNTIxN2U1ODVmOGQxYQ==',
#    'tracks': {'href': 'https://api.spotify.com/v1/playlists/5qxo1BUop98plBCslmwISf/tracks',
#     'total': 14},
#    'type': 'playlist',
#    'uri': 'spotify:playlist:5qxo1BUop98plBCslmwISf'},
#   {'collaborative': False,
#    'description': '',
#    'external_urls': {'spotify': 'https://open.spotify.com/playlist/2WLbugMJR0AcnrpCaPrsg8'},
#    'href': 'https://api.spotify.com/v1/playlists/2WLbugMJR0AcnrpCaPrsg8',
#    'id': '2WLbugMJR0AcnrpCaPrsg8',
#    'images': [{'height': 640,
#      'url': 'https://mosaic.scdn.co/640/5e29901a6fa1b461f0b6b4135cbaa3031dee9d0bab67616d0000b273098ac776f6f08211259e1238ab67616d0000b2733a26eb94c7e884f8bb28846fab67616d0000b273efe108fd52bee77d29571e0f',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://mosaic.scdn.co/300/5e29901a6fa1b461f0b6b4135cbaa3031dee9d0bab67616d0000b273098ac776f6f08211259e1238ab67616d0000b2733a26eb94c7e884f8bb28846fab67616d0000b273efe108fd52bee77d29571e0f',
#      'width': 300},
#     {'height': 60,
#      'url': 'https://mosaic.scdn.co/60/5e29901a6fa1b461f0b6b4135cbaa3031dee9d0bab67616d0000b273098ac776f6f08211259e1238ab67616d0000b2733a26eb94c7e884f8bb28846fab67616d0000b273efe108fd52bee77d29571e0f',
#      'width': 60}],
#    'name': 'SAMPLES',
#    'owner': {'display_name': 'garrettg45',
#     'external_urls': {'spotify': 'https://open.spotify.com/user/garrettg45'},
#     'href': 'https://api.spotify.com/v1/users/garrettg45',
#     'id': 'garrettg45',
#     'type': 'user',
#     'uri': 'spotify:user:garrettg45'},
#    'primary_color': None,
#    'public': True,
#    'snapshot_id': 'MjksNTA2Nzg4MzE0MTdjNzFkMWQ0ZDZlYWMzOTZiMDliMDQyOTA1ODIwYQ==',
#    'tracks': {'href': 'https://api.spotify.com/v1/playlists/2WLbugMJR0AcnrpCaPrsg8/tracks',
#     'total': 25},
#    'type': 'playlist',
#    'uri': 'spotify:playlist:2WLbugMJR0AcnrpCaPrsg8'},
#   {'collaborative': False,
#    'description': '',
#    'external_urls': {'spotify': 'https://open.spotify.com/playlist/6xNUho3ZCa7OpPT1lgWgIw'},
#    'href': 'https://api.spotify.com/v1/playlists/6xNUho3ZCa7OpPT1lgWgIw',
#    'id': '6xNUho3ZCa7OpPT1lgWgIw',
#    'images': [{'height': 640,
#      'url': 'https://mosaic.scdn.co/640/ab67616d0000b2734509204d0860cc0cc67e83dcab67616d0000b273e71dd15fc5bdefd5bff70452ab67616d0000b273f05e5ac32fdd79d100315a20cb72c27e95f1f897db1c750c2f837fa0b5e24bb9',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://mosaic.scdn.co/300/ab67616d0000b2734509204d0860cc0cc67e83dcab67616d0000b273e71dd15fc5bdefd5bff70452ab67616d0000b273f05e5ac32fdd79d100315a20cb72c27e95f1f897db1c750c2f837fa0b5e24bb9',
#      'width': 300},
#     {'height': 60,
#      'url': 'https://mosaic.scdn.co/60/ab67616d0000b2734509204d0860cc0cc67e83dcab67616d0000b273e71dd15fc5bdefd5bff70452ab67616d0000b273f05e5ac32fdd79d100315a20cb72c27e95f1f897db1c750c2f837fa0b5e24bb9',
#      'width': 60}],
#    'name': 'CHILL TIMELESS',
#    'owner': {'display_name': 'garrettg45',
#     'external_urls': {'spotify': 'https://open.spotify.com/user/garrettg45'},
#     'href': 'https://api.spotify.com/v1/users/garrettg45',
#     'id': 'garrettg45',
#     'type': 'user',
#     'uri': 'spotify:user:garrettg45'},
#    'primary_color': None,
#    'public': True,
#    'snapshot_id': 'MTE2LDY4MzcxMmIyYjA5MDcwYzU1YzM1N2Y1NDdkZGExOWNlMzM5NzE0NDU=',
#    'tracks': {'href': 'https://api.spotify.com/v1/playlists/6xNUho3ZCa7OpPT1lgWgIw/tracks',
#     'total': 251},
#    'type': 'playlist',
#    'uri': 'spotify:playlist:6xNUho3ZCa7OpPT1lgWgIw'},
#   {'collaborative': False,
#    'description': '',
#    'external_urls': {'spotify': 'https://open.spotify.com/playlist/0R9fBaNR3eF5TCfrXmV4Td'},
#    'href': 'https://api.spotify.com/v1/playlists/0R9fBaNR3eF5TCfrXmV4Td',
#    'id': '0R9fBaNR3eF5TCfrXmV4Td',
#    'images': [{'height': 640,
#      'url': 'https://mosaic.scdn.co/640/328af9644dff80954dbb7512f69a643f0ccb547b3844907e64009a8cbe1f9680849e5bc36f1d1483ab67616d0000b273395afe547468f53ce908d819ab67616d0000b27375d9ecf8d29744037d2d6064',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://mosaic.scdn.co/300/328af9644dff80954dbb7512f69a643f0ccb547b3844907e64009a8cbe1f9680849e5bc36f1d1483ab67616d0000b273395afe547468f53ce908d819ab67616d0000b27375d9ecf8d29744037d2d6064',
#      'width': 300},
#     {'height': 60,
#      'url': 'https://mosaic.scdn.co/60/328af9644dff80954dbb7512f69a643f0ccb547b3844907e64009a8cbe1f9680849e5bc36f1d1483ab67616d0000b273395afe547468f53ce908d819ab67616d0000b27375d9ecf8d29744037d2d6064',
#      'width': 60}],
#    'name': '👀WOKE👀',
#    'owner': {'display_name': 'garrettg45',
#     'external_urls': {'spotify': 'https://open.spotify.com/user/garrettg45'},
#     'href': 'https://api.spotify.com/v1/users/garrettg45',
#     'id': 'garrettg45',
#     'type': 'user',
#     'uri': 'spotify:user:garrettg45'},
#    'primary_color': None,
#    'public': True,
#    'snapshot_id': 'NTMsMjU0OTc0ZGVmNDU0OTVkYjQ0ZmE4YTUxODE4ZGMwZGVhYWNlOWI5ZA==',
#    'tracks': {'href': 'https://api.spotify.com/v1/playlists/0R9fBaNR3eF5TCfrXmV4Td/tracks',
#     'total': 43},
#    'type': 'playlist',
#    'uri': 'spotify:playlist:0R9fBaNR3eF5TCfrXmV4Td'},
#   {'collaborative': False,
#    'description': '',
#    'external_urls': {'spotify': 'https://open.spotify.com/playlist/1sI7XhWKJruiuJisfHr6yk'},
#    'href': 'https://api.spotify.com/v1/playlists/1sI7XhWKJruiuJisfHr6yk',
#    'id': '1sI7XhWKJruiuJisfHr6yk',
#    'images': [{'height': 640,
#      'url': 'https://mosaic.scdn.co/640/3f66a67cdc42c086eeef79f1e90c1d91e8de2b2cab67616d0000b273d79cfa3155b50beb5dbeeb9aab67616d0000b273ef23be59c0cdd6ed36a54c65ab67616d0000b273eff5e684bd079becefcae931',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://mosaic.scdn.co/300/3f66a67cdc42c086eeef79f1e90c1d91e8de2b2cab67616d0000b273d79cfa3155b50beb5dbeeb9aab67616d0000b273ef23be59c0cdd6ed36a54c65ab67616d0000b273eff5e684bd079becefcae931',
#      'width': 300},
#     {'height': 60,
#      'url': 'https://mosaic.scdn.co/60/3f66a67cdc42c086eeef79f1e90c1d91e8de2b2cab67616d0000b273d79cfa3155b50beb5dbeeb9aab67616d0000b273ef23be59c0cdd6ed36a54c65ab67616d0000b273eff5e684bd079becefcae931',
#      'width': 60}],
#    'name': 'HYPE TIMELESS',
#    'owner': {'display_name': 'garrettg45',
#     'external_urls': {'spotify': 'https://open.spotify.com/user/garrettg45'},
#     'href': 'https://api.spotify.com/v1/users/garrettg45',
#     'id': 'garrettg45',
#     'type': 'user',
#     'uri': 'spotify:user:garrettg45'},
#    'primary_color': None,
#    'public': True,
#    'snapshot_id': 'MTE0LDBmZmQ3ZGIzM2NkMzg2ZWYxMDg4NmZmZWRlMmJiNmZhNjE2MWM0NDE=',
#    'tracks': {'href': 'https://api.spotify.com/v1/playlists/1sI7XhWKJruiuJisfHr6yk/tracks',
#     'total': 261},
#    'type': 'playlist',
#    'uri': 'spotify:playlist:1sI7XhWKJruiuJisfHr6yk'},
#   {'collaborative': False,
#    'description': '',
#    'external_urls': {'spotify': 'https://open.spotify.com/playlist/2hmJpcVP060Vvi2NBJbCCa'},
#    'href': 'https://api.spotify.com/v1/playlists/2hmJpcVP060Vvi2NBJbCCa',
#    'id': '2hmJpcVP060Vvi2NBJbCCa',
#    'images': [{'height': 640,
#      'url': 'https://mosaic.scdn.co/640/40bd34ae7ea839e89139ace9205c3afd71e5a889ab67616d0000b27375d9ecf8d29744037d2d6064ab67616d0000b2737bcd3cd54e8399ae38cc6e64ab67616d0000b273ced248bb8dd18aa2da62f4f4',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://mosaic.scdn.co/300/40bd34ae7ea839e89139ace9205c3afd71e5a889ab67616d0000b27375d9ecf8d29744037d2d6064ab67616d0000b2737bcd3cd54e8399ae38cc6e64ab67616d0000b273ced248bb8dd18aa2da62f4f4',
#      'width': 300},
#     {'height': 60,
#      'url': 'https://mosaic.scdn.co/60/40bd34ae7ea839e89139ace9205c3afd71e5a889ab67616d0000b27375d9ecf8d29744037d2d6064ab67616d0000b2737bcd3cd54e8399ae38cc6e64ab67616d0000b273ced248bb8dd18aa2da62f4f4',
#      'width': 60}],
#    'name': 'LYRICAL EXCELLENCE',
#    'owner': {'display_name': 'garrettg45',
#     'external_urls': {'spotify': 'https://open.spotify.com/user/garrettg45'},
#     'href': 'https://api.spotify.com/v1/users/garrettg45',
#     'id': 'garrettg45',
#     'type': 'user',
#     'uri': 'spotify:user:garrettg45'},
#    'primary_color': None,
#    'public': True,
#    'snapshot_id': 'MTgsOThmNjZiZWJiMDA0ODM0ZWM4NDJiYTI1M2ZhM2UwOWU5YjE2NjBkYQ==',
#    'tracks': {'href': 'https://api.spotify.com/v1/playlists/2hmJpcVP060Vvi2NBJbCCa/tracks',
#     'total': 413},
#    'type': 'playlist',
#    'uri': 'spotify:playlist:2hmJpcVP060Vvi2NBJbCCa'},
#   {'collaborative': False,
#    'description': '',
#    'external_urls': {'spotify': 'https://open.spotify.com/playlist/4y3tHuUn61qOhxO97TVLrR'},
#    'href': 'https://api.spotify.com/v1/playlists/4y3tHuUn61qOhxO97TVLrR',
#    'id': '4y3tHuUn61qOhxO97TVLrR',
#    'images': [{'height': 640,
#      'url': 'https://mosaic.scdn.co/640/491e1e12de2b916758f62525f9db9af38223b2eb59fa6484e7bad6fc755cd0f2c1dc6b9109fce2b7ab67616d0000b27358f19bc139672039263a0ed8ab67616d0000b273b2592bea12d840fd096ef965',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://mosaic.scdn.co/300/491e1e12de2b916758f62525f9db9af38223b2eb59fa6484e7bad6fc755cd0f2c1dc6b9109fce2b7ab67616d0000b27358f19bc139672039263a0ed8ab67616d0000b273b2592bea12d840fd096ef965',
#      'width': 300},
#     {'height': 60,
#      'url': 'https://mosaic.scdn.co/60/491e1e12de2b916758f62525f9db9af38223b2eb59fa6484e7bad6fc755cd0f2c1dc6b9109fce2b7ab67616d0000b27358f19bc139672039263a0ed8ab67616d0000b273b2592bea12d840fd096ef965',
#      'width': 60}],
#    'name': 'EXCELLENCE',
#    'owner': {'display_name': 'garrettg45',
#     'external_urls': {'spotify': 'https://open.spotify.com/user/garrettg45'},
#     'href': 'https://api.spotify.com/v1/users/garrettg45',
#     'id': 'garrettg45',
#     'type': 'user',
#     'uri': 'spotify:user:garrettg45'},
#    'primary_color': None,
#    'public': True,
#    'snapshot_id': 'NTk2LDcxMzFlMmRkZWZiMDljYWMzM2U0M2QyOWRlMjk0MTdmNDBmOWI4YWY=',
#    'tracks': {'href': 'https://api.spotify.com/v1/playlists/4y3tHuUn61qOhxO97TVLrR/tracks',
#     'total': 528},
#    'type': 'playlist',
#    'uri': 'spotify:playlist:4y3tHuUn61qOhxO97TVLrR'}],
#  'limit': 50,
#  'next': None,
#  'offset': 0,
#  'previous': None,
#  'total': 26}
